# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
low_memory=False 
# %matplotlib notebook

# %%
df = pd.read_csv(r'C:\Users\giova\projetos\Employability-analysis-during-covid-19-Brazil\Evolução do Emprego Por Setor de Atividade Econômica (UF)- Saldo (Admissões - Desligamentos)/Evolução do Emprego Por Setor de Atividade Econômica - Saldo (Admissões - Desligamentos).csv', delimiter=';', skiprows=4)

# %%
for k in range(20): print (k, df.columns[k])
# Out:
# 0 Município
# 1 2002
# 2 2003
# 3 2004
# 4 2005
# 5 2006
# 6 2007
# 7 2008
# 8 2009
# 9 2010
# 10 2011
# 11 2012
# 12 2013
# 13 2014
# 14 2015
# 15 2016
# 16 2017
# 17 2018
# 18 2019
# 19 Total

# %%
df
# Out:
#                                     Município     2002     2003     2004  \
# 0                                Total Brasil  245.462  215.454  273.259
# 1                                       Norte   28.614   27.235   38.226
# 2                                    Rondônia    3.354    2.956    3.314
# 3                                        Acre    1.302  473.000    2.201
# 4                                    Amazonas    4.706    5.772    9.048
# 5                                     Roraima    1.099  442.000    1.394
# 6                                        Para   13.954   13.374   15.302
# 7                                       Amapa    1.702    2.313    2.332
# 8                                   Tocantins    2.497    1.905    4.635
# 9                                    Nordeste   74.966   59.671   73.680
# 10                                   Maranhão    5.321    4.973    6.214
# 11                                      Piaui    4.096    2.884    3.104
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Município  34 non-null     object
#  1   2002       33 non-null     float64
#  2   2003       33 non-null     float64
#  3   2004       33 non-null     float64
#  4   2005       33 non-null     float64
#  5   2006       33 non-null     float64
#  6   2007       33 non-null     float64
#  7   2008       33 non-null     float64
#  8   2009       33 non-null     float64
#  9   2010       33 non-null     float64
#  10  2011       33 non-null     float64
#  11  2012       33 non-null     float64
#  12  2013       33 non-null     float64
#  13  2014       33 non-null     float64
#  14  2015       33 non-null     float64
#  15  2016       33 non-null     float64
#  16  2017       33 non-null     float64
#  17  2018       33 non-null     float64
#  18  2019       33 non-null     float64
# ...

# %%
br = df.query('regiao == "Brasil" ')
br.tail(10).plot(x='data',y='casosAcumulado', figsize=(9,3), grid=True, color ='red')
plt.gcf().subplots_adjust(bottom=0.15) #serve para a xlabel n ficar cortada
## quatidade de casos novos diários desde o 125° dia da pandemia no brasil até o 129°(dia 03/07/2020)

plt.title('quatidade de casos acumulados desde o dia 24/06 até o dia 03/07')
plt.ylabel('quantidade de casos(por milhão)')
plt.xlabel('dias')
